# %% [markdown]
# # Chemical simulation interface
# This notebook provides an interface for a toy model of a chemical reaction in the gas phase.

# %% [markdown]
# ## Import libraries

# %%
from collider import Simulation
from ipycanvas import Canvas

# %% [markdown]
# ## Initialize and run the simulation
# Initialize the Simulation class with the desired parameters and run the simulation loop.

# %%
simulation = Simulation(Canvas, 800, 600, 100, temperature=300)
simulation.canvas
# Out:
# Canvas(height=600, width=800)

# %%
simulation.run()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 simulation.run()
#
# File ~\Documents\GitHub\DSA101\collider\collider.py:240, in Simulation.run(self)
#     238 while True:
#     239     self.update()
# --> 240     self.draw()
#     241     time.sleep(0.002)
#
# File ~\Documents\GitHub\DSA101\collider\collider.py:227, in Simulation.draw(self)
#     225 self.canvas.clear()
#     226 for sphere in self.spheres:
# --> 227     self.canvas.fill_style = sphere.color.fill
#     228     self.canvas.fill_circle(sphere.x, sphere.y, sphere.radius)
#     229     self.canvas.stroke_style = sphere.color.outline
#
# File ~\anaconda3\envs\DSA101\Lib\site-packages\ipycanvas\canvas.py:1553, in Canvas.__setattr__(self, name, value)
#    1552 def __setattr__(self, name, value):
# -> 1553     super(Canvas, self).__setattr__(name, value)
# ...
